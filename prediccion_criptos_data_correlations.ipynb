# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Import dataset
#df_Aave = pd.read_csv('coin_Aave.csv')
df_Binance = pd.read_csv('coin_BinanceCoin.csv')
df_BinancevsBitcoin = pd.read_csv('Binance_vs_Bitcoin.csv')
df_Bitcoin = pd.read_csv('coin_Bitcoin.csv')
df_Bitcoin_1 = pd.read_csv('coin_Bitcoin_1.csv')
df_Cardano = pd.read_csv('coin_Cardano.csv')
df_Chainlink = pd.read_csv('coin_ChainLink.csv')
df_CryptocomCoin = pd.read_csv('coin_CryptocomCoin.csv')
#df_Dogecoin = pd.read_csv('coin_Dogecoin.csv')
df_USD = pd.read_csv('coin_USDCoin.csv')
df_EOS = pd.read_csv('coin_EOS.csv')
df_Ethereum = pd.read_csv('coin_Ethereum.csv')
df_Iota = pd.read_csv('coin_Iota.csv')
df_Litecoin = pd.read_csv('coin_Litecoin.csv')
df_Monero = pd.read_csv('coin_Monero.csv')
df_NEM = pd.read_csv('coin_NEM.csv')
#df_Polkadot = pd.read_csv('coin_Polkadot.csv')
#df_Solana = pd.read_csv('coin_Solana.csv')
df_Stellar = pd.read_csv('coin_Stellar.csv')
df_Tether = pd.read_csv('coin_Tether.csv')
df_Tron = pd.read_csv('coin_Tron.csv')
df_XRP = pd.read_csv('coin_XRP.csv')

# %%
df_Binance.columns=['SNo_Bn','Name_Bn', 'Symbol_Bn', 'Date', 'High_Bn', 'Low_Bn', 'Open_Bn', 'Close_Bn', 'Volume_Bn', 'Marketcap_Bn']
df_Bitcoin.columns =['SNo_Btc','Name_Btc', 'Symbol_Btc', 'Date', 'High_Btc', 'Low_Btc', 'Open_Btc', 'Close_Btc', 'Volume_Btc', 'Marketcap_Btc']
df_Cardano.columns=['SNo_Cd','Name_Cd', 'Symbol_Cd', 'Date', 'High_Cd', 'Low_Cd', 'Open_Cd', 'Close_Cd', 'Volume_Cd', 'Marketcap_Cd']
df_Chainlink.columns=['SNo_Chl','Name_Chl', 'Symbol_Chl', 'Date', 'High_Chl', 'Low_Chl', 'Open_Chl', 'Close_Chl', 'Volume_Chl', 'Marketcap_Chl']
df_CryptocomCoin.columns=['SNo_Cc','Name_Cc', 'Symbol_Cc', 'Date', 'High_Cc', 'Low_Cc', 'Open_Cc', 'Close_Cc', 'Volume_Cc', 'Marketcap_Cc']
df_EOS.columns=['SNo_EOS','Name_EOS', 'Symbol_EOS', 'Date', 'High_EOS', 'Low_EOS', 'Open_EOS', 'Close_EOS', 'Volume_EOS', 'Marketcap_EOS']
df_Ethereum.columns=['SNo_Eth','Name_Eth', 'Symbol_Eth', 'Date', 'High_Eth', 'Low_Eth', 'Open_Eth', 'Close_Eth', 'Volume_Eth', 'Marketcap_Eth']
df_Iota.columns=['SNo_Io','Name_Io', 'Symbol_Io', 'Date', 'High_Io', 'Low_Io', 'Open_Io', 'Close_Io', 'Volume_Io', 'Marketcap_Io']
df_Litecoin.columns=['SNo_Ltc','Name_Ltc', 'Symbol_Ltc', 'Date', 'High_Ltc', 'Low_Ltc', 'Open_Ltc', 'Close_Ltc', 'Volume_Ltc', 'Marketcap_Ltc']
df_Monero.columns=['SNo_Mn','Name_Mn', 'Symbol_Mn', 'Date', 'High_Mn', 'Low_Mn', 'Open_Mn', 'Close_Mn', 'Volume_Mn', 'Marketcap_Mn']
df_NEM.columns=['SNo_NEM','Name_NEM', 'Symbol_NEM', 'Date', 'High_NEM', 'Low_NEM', 'Open_NEM', 'Close_NEM', 'Volume_NEM', 'Marketcap_NEM']
df_Stellar.columns=['SNo_St','Name_St', 'Symbol_St', 'Date', 'High_St', 'Low_St', 'Open_St', 'Close_St', 'Volume_St', 'Marketcap_St']
df_Tether.columns=['SNo_Tth','Name_Tth', 'Symbol_Tth', 'Date', 'High_Tth', 'Low_Tth', 'Open_Tth', 'Close_Tth', 'Volume_Tth', 'Marketcap_Tth']
df_Tron.columns=['SNo_Tr','Name_Tr', 'Symbol_Tr', 'Date', 'High_Tr', 'Low_Tr', 'Open_Tr', 'Close_Tr', 'Volume_Tr', 'Marketcap_Tr']
df_XRP.columns=['SNo_XRP','Name_XRP', 'Symbol_XRP', 'Date', 'High_XRP', 'Low_XRP', 'Open_XRP', 'Close_XRP', 'Volume_XRP', 'Marketcap_XRP']

frames=[df_Binance,df_Cardano,df_Chainlink,df_CryptocomCoin,df_EOS,df_Ethereum,df_Iota,df_Litecoin,df_Monero,df_NEM,df_Stellar,df_Tether,df_Tron,df_XRP]
#DF=pd.concat(frames)
#DF = pd.merge(pd.merge(df_Binance,df_Cardano,on='Date'),df_Chainlink,on='Date')
DF = df_USD.merge(df_Bitcoin.merge(df_XRP.merge(df_Tron.merge(df_Stellar.merge(df_NEM.merge(df_Monero.merge(df_Litecoin.merge(df_Iota.merge(df_Ethereum.merge(df_EOS.merge(df_EOS.merge(df_CryptocomCoin.merge(df_Chainlink.merge(df_Cardano.merge(df_Binance, on="Date"), on="Date"), on="Date"), on="Date"), on="Date"), on="Date"), on="Date"), on="Date"), on="Date"), on="Date"), on="Date"), on="Date"), on="Date"),on="Date"),on="Date")

# %%
JEFOTA = pd.read_csv('/content/JEFOTA.csv')

# %%
JEFOTA_con_USD =  df_USD.merge(JEFOTA,on="Date")

# %%
JEFOTA_con_USD.to_csv(r"/content/sample_data/JEFOTA_con_USD.csv", index=False)

# %%
DfForCorrM = JEFOTA_con_USD[["Open",'Open_Btc',"Close_Btc",'Prev_Close_Bn','Prev_Close_Cd','Prev_Close_Chl','Prev_Close_Cc', 'Prev_Close_Eth', 'Prev_Close_Io', "Prev_Close_Ltc", 'Prev_Close_Mn', 'Prev_Close_NEM', 'Prev_Close_St', 'Prev_Close_Tr','Prev_Close_XRP']]

# %%
DfForCorrM
# Out:
#          Open      Open_Btc     Close_Btc  Prev_Close_Bn  Prev_Close_Cd  \
# 0    1.004841   3236.274773   3252.839026       4.563012       0.028274
# 1    1.027452   3253.122993   3545.864761       4.645258       0.029103
# 2    1.014195   3544.761565   3696.059128       5.110017       0.032824
# 3    1.009053   3706.824850   3745.950765       5.600270       0.034735
# 4    1.021235   3742.195183   4134.441203       5.491901       0.034545
# ..        ...           ...           ...            ...            ...
# 929  1.000177  33549.600177  33897.048590     288.218405       1.335611
# 930  1.000048  33854.421362  34668.548402     287.423094       1.394397
# 931  0.999956  34665.564866  35287.779766     298.237117       1.406836
# 932  0.999565  35284.344430  33746.002456     307.732096       1.458184
# 933  1.000501  33723.509655  34235.193451     302.377980       1.404898
#
#      Prev_Close_Chl  Prev_Close_Cc  Prev_Close_Eth  Prev_Close_Io  \
# ...

# %%
#df_JEFOTA = pd.read_csv('/content/sample_data/JEFOTA_con_USD.csv')

# %%
corrmatrix = DfForCorrM.corr()
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(corrmatrix,annot=True)
plt.show()

# %%
#Gráficas bivariables 
bivar = sns.PairGrid(DfForCorrM)
bivar.map(sns.scatterplot)
